# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Now import
from helper import percent_missing
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 7
#       4 import seaborn as sns
#       6 # Now import
# ----> 7 from helper import percent_missing
#
# ImportError: cannot import name 'percent_missing' from 'helper' (/Users/home/Documents/Projects/ai-engineering-portfolio/classical-ml/house-price-prediction/notebooks/../src/utils/helper.py)

# %%
df = pd.read_csv("../data/raw/train.csv")

# %%
df.head()

# %%
df.describe()

# %%
df.info()

# %%
def percent_missing(df):
    percent_nan = 100 * (df.isnull().sum())/len(df)
    percent_nan = percent_nan[percent_nan > 0].sort_values()
    return percent_nan

# %%
## find percentage of data missing in each column
percent_missing(df)

# %%
## get information regarding the numerical columns
num_cols = df.select_dtypes(include= np.number).columns.to_list()
df[num_cols].describe().transpose()

# %%
## get value count for each categorical column
cat_cols = df.select_dtypes(include = 'object').columns.to_list()
for col in cat_cols:
    print(df[col].value_counts())

# %%
## plot histogram for each numerical column to see data spread
for col in num_cols:
    plt.figure(figsize=(6,6))
    sns.histplot(data =df, x = col, kde=True)
    plt.title("Histogram for {}".format(col))

# %%
##boxplot of numerical columns to check for outliers
for col in num_cols:
    plt.figure(figsize=(6,4))
    sns.boxplot( x = df[col])
    plt.title(f"Box Plot for {col}")

# %%
##count plot for categorical columns
for col in cat_cols:
    plt.figure(figsize=(6,4))
    sns.countplot(x = df[col])
    plt.title(f"Count plot for {col}")
    plt.xticks(rotation=90)

# %%
##check correlation
df[num_cols].corr()

# %%
##heatmap
plt.figure(figsize=(16,12))
sns.heatmap(data= df[num_cols].corr(),cmap='viridis')

# %%
corr = df[num_cols].corr()['SalePrice'].sort_values()
plt.figure(figsize=(10,8))
sns.barplot(data = corr)
plt.xticks(rotation=90);
